# %% [markdown]
# <a href="https://colab.research.google.com/github/tariqzia5/Python_P/blob/main/Tariq_Zia_Python_Data_Manipuations_Assignment_AirBnB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Data Manipulations Assignment
# Instructor- Venkata Reddy Konasani
# https://statinfer.com/

# %% [markdown]
# Airbnb, Inc. (/ˌɛərˌbiːɛnˈbiː/ AIR-BEE-en-BEE) is an American company that operates an online marketplace for lodging, primarily homestays for vacation rentals, and tourism activities. Based in San Francisco, California, the platform is accessible via website and mobile app. Airbnb does not own any of the listed properties; instead, it profits by receiving commission from each booking. The company was founded in 2008 by Brian Chesky, Nathan Blecharczyk, and Joe Gebbia. Airbnb is a shortened version of its original name, AirBedandBreakfast.com.
#
# **Context**
# Since 2008, guests and hosts have used Airbnb to expand on traveling possibilities and present more unique, personalized way of experiencing the world. This dataset describes the listing activity and metrics in NYC, NY for 2019.
#
# **Content**
# This data file includes all needed information to find out more about hosts, geographical availability, necessary metrics to make predictions and draw conclusions.

# %% [markdown]
# ##What is Air BnB? What is their business?

# %% [markdown]
# ## 1.Import the dataset – AirBnB New York data AB_NYC_2019.csv.
#
# Dataset location "https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day2_Files/Datasets/AB_NYC_2019.xlsx"
#
# sheet_name="AB_NYC_2019"

# %%
import pandas as pd

# %%
airbnb_data=pd.read_excel("https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day2_Files/Datasets/AB_NYC_2019.xlsx")

# %%
airbnb_data=pd.read_csv("https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day2_Files/Datasets/AB_NYC_2019.csv")

# %%
airbnb_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## 2.How many rows and columns are there in the dataset?

# %%
airbnb_data.shape
# Out:
# (48895, 16)

# %% [markdown]
# ## 3.Print the column names

# %%
airbnb_data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ## 4.Print some sample rows from the data

# %%
airbnb_data[0:2]
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  2018-10-19               0.21
# 1    225               1                 45  2019-05-21               0.38
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355

# %%
airbnb_data.sample(2)
# Out:
#             id                                name   host_id host_name  \
# 747     270315                 Bed-stuy Royal Room   1398639    Juliet
# 10814  8326753  Prime Location in Theatre District  34934128       Aly
#
#       neighbourhood_group       neighbourhood  latitude  longitude  \
# 747              Brooklyn  Bedford-Stuyvesant  40.68812  -73.93254
# 10814           Manhattan    Theater District  40.76095  -73.98668
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 747    Private room     34              10                 16  2019-03-27
# 10814  Private room    150               2                  3  2017-06-19
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 747                 0.19                               3               216
# 10814               0.08                               1                 0

# %% [markdown]
# ## 5.What are the column data types?

# %%
airbnb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# [link text](https://)## 6.Are there any missing values in the data?, if yes, then how many are there in each column?

# %% [markdown]
# ## 7.Create a new dataset by considering only numerical columns.

# %%
from numpy import int64
data_set=airbnb_data.select_dtypes(include=int64)
data_set
# Out:
#              id   host_id  price  minimum_nights  number_of_reviews  \
# 0          2539      2787    149               1                  9
# 1          2595      2845    225               1                 45
# 2          3647      4632    150               3                  0
# 3          3831      4869     89               1                270
# 4          5022      7192     80              10                  9
# ...         ...       ...    ...             ...                ...
# 48890  36484665   8232441     70               2                  0
# 48891  36485057   6570630     40               4                  0
# 48892  36485431  23492952    115              10                  0
# 48893  36485609  30985759     55               1                  0
# 48894  36487245  68119814     90               7                  0
#
#        calculated_host_listings_count  availability_365
# 0                                   6               365
# ...

# %%
data_set=airbnb_data.select_dtypes(include=object)
data_set
# Out:
#                                                     name      host_name  \
# 0                     Clean & quiet apt home by the park           John
# 1                                  Skylit Midtown Castle       Jennifer
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      Elisabeth
# 3                        Cozy Entire Floor of Brownstone    LisaRoxanne
# 4       Entire Apt: Spacious Studio/Loft by central park          Laura
# ...                                                  ...            ...
# 48890    Charming one bedroom - newly renovated rowhouse        Sabrina
# 48891      Affordable room in Bushwick/East Williamsburg        Marisol
# 48892            Sunny Studio at Historical Neighborhood  Ilgar & Aysel
# 48893               43rd St. Time Square-cozy single bed            Taz
# 48894  Trendy duplex in the very heart of Hell's Kitchen     Christophe
#
#       neighbourhood_group       neighbourhood        room_type last_review
# ...

# %% [markdown]
# ## 8.Create a new dataset by considering only Non-numerical columns.

# %%
data_set=airbnb_data.select_dtypes(include=object)
data_set
# Out:
#                                                     name      host_name  \
# 0                     Clean & quiet apt home by the park           John
# 1                                  Skylit Midtown Castle       Jennifer
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      Elisabeth
# 3                        Cozy Entire Floor of Brownstone    LisaRoxanne
# 4       Entire Apt: Spacious Studio/Loft by central park          Laura
# ...                                                  ...            ...
# 48890    Charming one bedroom - newly renovated rowhouse        Sabrina
# 48891      Affordable room in Bushwick/East Williamsburg        Marisol
# 48892            Sunny Studio at Historical Neighborhood  Ilgar & Aysel
# 48893               43rd St. Time Square-cozy single bed            Taz
# 48894  Trendy duplex in the very heart of Hell's Kitchen     Christophe
#
#       neighbourhood_group       neighbourhood        room_type last_review
# ...

# %% [markdown]
# ##  9.Create a subset by considering only room_type=“Private room”

# %%
airbnb_data1=airbnb_data[(airbnb_data["room_type"]=="Private room")]
airbnb_data1
# Out:
#              id                                               name    host_id  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 6          5121                                    BlissArtsSpace!       7356
# 7          5178                   Large Furnished Room Near B'way        8967
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# ...         ...                                                ...        ...
# 48888  36484087  Spacious Room w/ Private Rooftop, Central loca...  274321313
# 48889  36484363                                 QUIT PRIVATE HOUSE  107716952
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %% [markdown]
# ## 10.Create a subset by considering only room_type="Private room" and "price" < 100

# %%
c=airbnb_data[(airbnb_data["room_type"]=="Private room") & airbnb_data["price"]<1000]
c
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## 11.Sort the data based on number_of_reviews. Both ascending and descending

# %%
a=airbnb_data.sort_values("number_of_reviews")
a
# Out:
#              id                                               name    host_id  \
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
# 28711  22204856          Room available in 3 BD Brooklyn apartment    1819657
# 15661  12650830                             Quiet room in Bed-Stuy   68585649
# 40011  31076156                               长岛豪华公寓单间卧室低价短租交通无敌便利  232169947
# 7707    5826468                Large 2 bed 2 bath w private patio!   27894798
# ...         ...                                                ...        ...
# 13495  10101135                            Room Near JFK Twin Beds   47621202
# 2015     891117                       Private Bedroom in Manhattan    4734398
# 2030     903947                     Beautiful Bedroom in Manhattan    4734398
# 2031     903972                         Great Bedroom in Manhattan    4734398
# 11759   9145202                            Room near JFK Queen Bed   47621202
#
# ...

# %%
a=airbnb_data.sort_values("number_of_reviews",ascending=False)
a
# Out:
#              id                                               name   host_id  \
# 11759   9145202                            Room near JFK Queen Bed  47621202
# 2031     903972                         Great Bedroom in Manhattan   4734398
# 2030     903947                     Beautiful Bedroom in Manhattan   4734398
# 2015     891117                       Private Bedroom in Manhattan   4734398
# 13495  10101135                            Room Near JFK Twin Beds  47621202
# ...         ...                                                ...       ...
# 12724   9746225                Sunny, clean, contemporary Soho Apt  14005489
# 12721   9740386                          Chic 1 BR in Meatpackiing  50255130
# 12717   9739888                One room in a 4 bedroom apaprtment.  50252837
# 12716   9738605                                     Bedford Palace  50054847
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## 12.Sort the data by price descending and by number_of_reviews

# %%
b=airbnb_data.sort_values(["price","number_of_reviews"],ascending=False)
b
# Out:
#              id                                               name    host_id  \
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 9151    7003697                Furnished room in Astoria apartment   20582832
# 29238  22436899                                1-BR Lincoln Center   72390391
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 6530    4737930                                 Spanish Harlem Apt    1235070
# ...         ...                                                ...        ...
# 26866  21304320             Best Coliving space ever! Shared room.  101970559
# 25778  20624541      Modern apartment in the heart of Williamsburg   10132166
# 26841  21291569  Coliving in Brooklyn! Modern design / Shared room  101970559
# 23161  18750597  Huge Brooklyn Brownstone Living, Close to it all.    8993084
# 26259  20933849                              the best you can find   13709292
#
# ...

# %% [markdown]
# ## 13.Sort the data by price descending and select first ten rows.

# %%
c=airbnb_data.sort_values("price",ascending=False)

# %%
d=c[:11]
d
# Out:
#              id                                               name    host_id  \
# 9151    7003697                Furnished room in Astoria apartment   20582832
# 17692  13894339    Luxury 1 bedroom apt. -stunning Manhattan views    5143901
# 29238  22436899                                1-BR Lincoln Center   72390391
# 40433  31340283  2br - The Heart of NYC: Manhattans Lower East ...    4382127
# 12342   9528920                Quiet, Clean, Lit @ LES & Chinatown    3906464
# 6530    4737930                                 Spanish Harlem Apt    1235070
# 30268  23377410  Beautiful/Spacious 1 bed luxury flat-TriBeCa/Soho   18128455
# 4377    2953058                                      Film Location    1177497
# 29662  22779726          East 72nd Townhouse by (Hidden by Airbnb)  156158778
# 42523  33007610                70' Luxury MotorYacht on the Hudson    7407743
# 45666  34895693                               Gem of east Flatbush  262534951
#
# ...

# %% [markdown]
# ## 14.Drop the id column from the data crate a new dataset.

# %%
airbnb_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
import numpy as np

# %%
drop_d=airbnb_data.drop(["id"],axis=1)
drop_d
# Out:
#                                                     name   host_id  \
# 0                     Clean & quiet apt home by the park      2787
# 1                                  Skylit Midtown Castle      2845
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3                        Cozy Entire Floor of Brownstone      4869
# 4       Entire Apt: Spacious Studio/Loft by central park      7192
# ...                                                  ...       ...
# 48890    Charming one bedroom - newly renovated rowhouse   8232441
# 48891      Affordable room in Bushwick/East Williamsburg   6570630
# 48892            Sunny Studio at Historical Neighborhood  23492952
# 48893               43rd St. Time Square-cozy single bed  30985759
# 48894  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 0               John            Brooklyn          Kensington  40.64749
# ...

# %% [markdown]
# ## 15.Create a new column in the data, discount_price = price*0.75

# %%
airbnb_data["discount_price"]=airbnb_data["price"]*.75
airbnb_data
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ## 16.Shuffle the data - Create a new column , fill it with random numbers between 1 to 10, then sort the data based on this column.

# %%
airbnb_data[x]=random.sample(xrange(10),len(airbnb_data))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-8559675f23ff> in <module>
# ----> 1 airbnb_data[x]=random.sample(xrange(10),len(airbnb_data))
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'sample'

# %% [markdown]
# ## 17.Are there any duplicate rows in the overall dataset?, if yes how many?

# %%
duplicate_value=airbnb_data.duplicated()
duplicate_value
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48890    False
# 48891    False
# 48892    False
# 48893    False
# 48894    False
# Length: 48895, dtype: bool

# %%
duplicate_value.count()
# Out:
# 48895

# %%
duplicate_value.value_counts()
# Out:
# False    48895
# dtype: int64

# %% [markdown]
# ## 18.Are there any duplicates based on host_id?

# %%
duplicate_value1=airbnb_data["host_id"].duplicated()
duplicate_value1.value_counts()
# Out:
# False    37457
# True     11438
# Name: host_id, dtype: int64

# %% [markdown]
# ## 19.Import the AB_NYC_2019_Reviews.csv data. Join this data to  to include ratings in the current table.
#
# AB_NYC_2019_Reviews.csv - https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day2_Files/Datasets/AB_NYC_2019_Reviews.csv

# %%
AB_NYC_2019=pd.read_csv("https://raw.githubusercontent.com/venkatareddykonasani/python_5days/master/Day2_Files/Datasets/AB_NYC_2019_Reviews.csv")

# %%
AB_NYC_2019
# Out:
#              id                                               name   host_id  \
# 0         21644                          Upper Manhattan, New York     82685
# 1         32363                 Fully Furnished Basement Apartment    140025
# 2         59121                  Nice, clean, safe, convenient 3BR    204539
# 3         60673                 Private Room/bath Luxurious Harlem    249372
# 4         64707  Amazing  Sunny & Breezy Home In the Heart of  NYC      7310
# ...         ...                                                ...       ...
# 38838  10101135                            Room Near JFK Twin Beds  47621202
# 38839    891117                       Private Bedroom in Manhattan   4734398
# 38840    903947                     Beautiful Bedroom in Manhattan   4734398
# 38841    903972                         Great Bedroom in Manhattan   4734398
# 38842   9145202                            Room near JFK Queen Bed  47621202
#
# ...

# %%
rating1=pd.merge(airbnb_data,AB_NYC_2019,how="outer",on="host_id")
rating1
# Out:
#             id_x                                             name_x  \
# 0           2539                 Clean & quiet apt home by the park
# 1           2539                 Clean & quiet apt home by the park
# 2           2539                 Clean & quiet apt home by the park
# 3           2539                 Clean & quiet apt home by the park
# 4           2539                 Clean & quiet apt home by the park
# ...          ...                                                ...
# 208242  36482783        Brooklyn Oasis in the heart of Williamsburg
# 208243  36483010                    Comfy 1 Bedroom in Midtown East
# 208244  36484087  Spacious Room w/ Private Rooftop, Central loca...
# 208245  36485431            Sunny Studio at Historical Neighborhood
# 208246  36487245  Trendy duplex in the very heart of Hell's Kitchen
#
#           host_id    host_name_x neighbourhood_group   neighbourhood  \
# 0            2787           John            Brooklyn      Kensington
# ...

# %%
rating2=pd.merge(airbnb_data,AB_NYC_2019,how="outer",on="id")
rating2
# Out:
#              id                                             name_x  host_id_x  \
# 0          2539                 Clean & quiet apt home by the park       2787
# 1          2595                              Skylit Midtown Castle       2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !       4632
# 3          3831                    Cozy Entire Floor of Brownstone       4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# ...         ...                                                ...        ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse    8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg    6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood   23492952
# 48893  36485609               43rd St. Time Square-cozy single bed   30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen   68119814
#
# ...

# %% [markdown]
# ## 20.What is the average room price in each neighbourhood ? Write the code to generate the below output
# * Bronx             87.496792
# * Brooklyn         124.383207
# * Manhattan        196.875814
# * Queens            99.517649
# * Staten Island    114.812332

# %%
m=rating1.groupby("neighbourhood").agg({'room_type':["count"],'price':['mean']})
m
# Out:
#                 room_type       price
#                     count        mean
# neighbourhood
# Allerton              105   98.761905
# Arden Heights           4   67.250000
# Arrochar               84   79.047619
# Arverne               120  153.958333
# Astoria              1954   89.950870
# ...                   ...         ...
# Windsor Terrace       227  123.757709
# Woodhaven             265   65.883019
# Woodlawn               19   52.000000
# Woodrow                 1  700.000000
# Woodside             2356   52.977504
#
# [221 rows x 2 columns]

# %%
m
# Out:
#                       price
#                        mean
# neighbourhood
# Allerton          98.761905
# Arden Heights     67.250000
# Arrochar          79.047619
# Arverne          153.958333
# Astoria           89.950870
# ...                     ...
# Windsor Terrace  123.757709
# Woodhaven         65.883019
# Woodlawn          52.000000
# Woodrow          700.000000
# Woodside          52.977504
#
# [221 rows x 1 columns]

# %%
n=rating1.groupby()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-dbf388727f6b> in <module>
# ----> 1 n=rating1.groupby()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7624
#    7625         if level is None and by is None:
# -> 7626             raise TypeError("You have to supply one of 'by' and 'level'")
#    7627         axis = self._get_axis_number(axis)
#    7628
#
# TypeError: You have to supply one of 'by' and 'level'

# %% [markdown]
# ## 21.In every neighbourhood_group display the number of rooms, average price of the rooms, minimum price, maximum price and average ratings

# %%
k=rating1.groupby("neighbourhood").agg({'room_type':["count"],'price':['mean','max','min'],'Rating':['mean']})
k
# Out:
#                 room_type       price                Rating
#                     count        mean    max  min      mean
# neighbourhood
# Allerton              105   98.761905    450   33  2.397059
# Arden Heights           4   67.250000     83   41  2.100000
# Arrochar               84   79.047619    625   32  1.953571
# Arverne               120  153.958333   1500   35  3.012613
# Astoria              1954   89.950870  10000   25  2.428811
# ...                   ...         ...    ...  ...       ...
# Windsor Terrace       227  123.757709    450   38  2.246078
# Woodhaven             265   65.883019    250   10  2.578039
# Woodlawn               19   52.000000     85   29  1.884211
# Woodrow                 1  700.000000    700  700       NaN
# Woodside             2356   52.977504    500   28  2.276397
#
# [221 rows x 5 columns]

# %% [markdown]
# ## 22.What is the count of rooms in every neighbourhood_group under every room_type?
# [Result](https://github.com/venkatareddykonasani/Datasets/blob/master/Archives/output1.PNG?raw=true)

# %%
s=rating1.groupby("neighbourhood")["room_type"].value_counts()
s
# Out:
# neighbourhood  room_type
# Allerton       Private room         68
#                Entire home/apt      37
# Arden Heights  Entire home/apt       3
#                Private room          1
# Arrochar       Private room         64
#                                   ...
# Woodlawn       Shared room           2
# Woodrow        Entire home/apt       1
# Woodside       Private room       2264
#                Entire home/apt      91
#                Shared room           1
# Name: room_type, Length: 540, dtype: int64

# %% [markdown]
# ## 23.What is the count of and percentage of rooms in every neighbourhood_group under every room_type?
#
# [Result](https://github.com/venkatareddykonasani/Datasets/blob/master/Archives/output2.PNG?raw=true)

# %%
r=rating1.groupby("neighbourhood")["room_type"].
r
